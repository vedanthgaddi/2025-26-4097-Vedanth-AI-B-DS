# %% [markdown]
# <a href="https://colab.research.google.com/github/vedanthgaddi/2025-26-4097-Vedanth-AI-B-DS/blob/main/21_04_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#27 confusuion matrix
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score,roc_curve,auc
import matplotlib.pyplot as plt
y_true=[1,0,1,0,1,0,1,0]
y_pred=[1,1,1,0,0,0,1,0]
cm=confusion_matrix(y_true,y_pred)
print("confusion matrix:",cm)
print("precision:",precision_score(y_true,y_pred))
print("Recall:", recall_score(y_true,y_pred))
print("F1:",f1_score(y_true,y_pred))
y_score=[0.9,0.6,0.8,0.3,0.4,0.2,0.85,0.1]
fpr,tpr,_=roc_curve(y_true,y_score)
roc_auc=auc(fpr,tpr)
print("AUC:",roc_auc)
plt.plot(fpr,tpr)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ploc curve")
plt.show()
# Out:
# confusion matrix: [[3 1]
#  [1 3]]
# precision: 0.75
# Recall: 0.75
# F1: 0.75
# AUC: 0.9375

# %%
#28 svm
from sklearn import svm
x=[[2,2],[4,4],[2,0],[0,2]]
y=[1,1,-1,-1]
model=svm.SVC(kernel='linear')
model.fit(x,y)
print(model.predict([[0,0]]))
# Out:
# [-1]

# %%
#29 polynomial regression
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
x=np.array([1,2,3,4]).reshape(-1,1)
y=np.array([1,4,9,16])
poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
model=LinearRegression()
model.fit(x_poly,y)
y_pred=model.predict(x_poly)
plt.scatter(x,y)
plt.plot(x,y_pred)
plt.show()

# %%
#30 decision tree
from sklearn.tree import DecisionTreeClassifier
x=[[1,1],[1,0],[0,1],[0,0]]
y=[0,1,1,0]
model=DecisionTreeClassifier()
model.fit(x,y)
print(model.predict([[0,1]]))
# Out:
# [1]

# %%
#30 decision tree
from sklearn.tree import DecisionTreeClassifier
x=[[1,1,1],[1,0,1],[0,1,0],[0,0,0]]
y=[1,1,0,0]
model=DecisionTreeClassifier()
model.fit(x,y)
print(model.predict([[1,0,1]]))
# Out:
# [1]

# %%
from sklearn.ensemble import RandomForestClassifier
x=[[1,1],[1,0],[0,1],[0,0]]
y=[1,0,0,0]
model=RandomForestClassifier()
model.fit(x,y)
print(model.predict([[0,1]]))
# Out:
# [0]
